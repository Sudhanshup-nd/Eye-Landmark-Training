# %%
from model import EyeLandmarkModel


model=EyeLandmarkModel()

print(model)
# Out:
# EyeLandmarkModel(
#   (backbone): ResNet(
#     (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
def hook_fn(module, input, output):
    print(f"\n--- Layer: {module} ---")
    print(f"Input shape: {[i.shape for i in input]}")
    print(f"Output shape: {output.shape}")
    # To print actual data, uncomment:
    # print("Input data:", input)
    # print("Output data:", output)
    return None

# Attach hook to layer1's first block
hook = model.backbone.layer4[0].register_forward_hook(hook_fn)


hook1 = model.backbone.conv1.register_forward_hook(hook_fn)
hook2 = model.landmark_head[0].register_forward_hook(hook_fn)


some_input_tensor = torch.randn(1, 1, 64, 64)  # Example input tensor

out = model(some_input_tensor)  # input shape [B, 1, H, W]

hook1.remove()
hook2.remove()
# Out:
# --- Layer: Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False) ---
# Input shape: [torch.Size([1, 1, 64, 64])]
# Output shape: torch.Size([1, 64, 32, 32])
#
# --- Layer: Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False) ---
# Input shape: [torch.Size([1, 1, 64, 64])]
# Output shape: torch.Size([1, 64, 32, 32])
#
# --- Layer: BasicBlock(
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) ---
# Input shape: [torch.Size([1, 64, 16, 16])]
# Output shape: torch.Size([1, 64, 16, 16])
#
# --- Layer: BasicBlock(
# ...
